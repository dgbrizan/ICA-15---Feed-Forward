# %% [markdown]
# # Feed Forward network
#
# Get PyTorch from https://pytorch.org/get-started/locally/

# %% [markdown]
# ## 1. Handling data

# %%
# Pima Indians Diabetes dataset
# https://www.kaggle.com/uciml/pima-indians-diabetes-database
# (Can't find it on UCI.)
# This is NOT an optimal dataset for NNs because it's relatively small (< 800 instances)
# ... but it's useful to go through the steps with something we can train and test in 1 meeting.

import pandas as pd

df = pd.read_csv('diabetes.csv')
df

# %%
# Split the data into train, test, valid

# %%
# Convert the data to a tensor

# %%
# Wrap the data in a Dataset

# %%
# Encase the Dataset in a DataLoader

# %% [markdown]
# ## 2. Create the Neural Network

# %% [markdown]
# ## 3. Forward the data through the Neural Network
